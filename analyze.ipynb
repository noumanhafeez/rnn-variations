# %%
import pandas as pd

# %%
df = pd.read_csv('scholar_papers.csv')
df.head(50)
# Out:
#                                                 Title  \
# 0   [HTML] Artificial intelligence revolutionises ...
# 1   AI-driven weather forecasts for climate adapta...
# 2   [PDF] Climate resilience with AI-powered weath...
# 3   AI Weather and Climate Prediction and Applicat...
# 4   Ai foundation models for weather and climate: ...
# 5   [PDF] Weather forecasting: a systematic review...
# 6   Meteorologists predict better weather forecast...
# 7     Artificial intelligence for weather forecasting
# 8   [HTML] Hybrid forecasting: blending climate pr...
# 9   AI‐driven weather forecasts to accelerate clim...
# 10  AI-based prediction of high-impact weather and...
# 11  Integration of IoT-AI powered local weather fo...
# 12  Advancing weather and climate forecasting for ...
# 13  Enhancing climate forecasting with AI: Current...
# 14  Predictability study of weather and climate ev...
# 15  Do AI models produce better weather forecasts ...
# ...
